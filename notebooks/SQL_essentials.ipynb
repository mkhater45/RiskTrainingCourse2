# %%
import duckdb
import time
import pandas as pd

# Create a database connection object
conn = duckdb.connect("..//risk.duckdb")

# %%
# 2. Write the query
query = f"""
describe table accounts
--select count(*) as num_trx, sum(amount_paid) as sum_trx from transactions where payment_format = 'Wire'

"""

# %%
# 3. Time and execute the query
start_time = time.time()

results_frame = pd.read_sql_query(query, conn)

elapsed = time.time() - start_time

print(f" Query executed in {elapsed:.4f} seconds across millions of rows!\n")
conn.close()

# 4. Display the DataFrame in the notebook output
results_frame
# Out:
#  Query executed in 0.0050 seconds across millions of rows!
# /tmp/ipykernel_2291/1253819310.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   results_frame = pd.read_sql_query(query, conn)
#       column_name column_type null   key default extra
# 0       Bank_Name     VARCHAR  YES  None    None  None
# 1         Bank_ID      BIGINT  YES  None    None  None
# 2  Account_Number     VARCHAR  YES  None    None  None
# 3       Entity_ID     VARCHAR  YES  None    None  None
# 4     Entity_Name     VARCHAR  YES  None    None  None
