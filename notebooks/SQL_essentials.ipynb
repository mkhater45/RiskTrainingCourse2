# %%
import duckdb
import time
import pandas as pd

# Location of the data on a Microsoft Cloud server in .parquet format
TRANSACTIONS_TABLE ='https://tahastorage.blob.core.windows.net/training-public/transactions.parquet'
ACCOUNTS_TABLE ='https://tahastorage.blob.core.windows.net/training-public/accounts.parquet'

# Create a database connection object
conn = duckdb.connect()

# %%
# 2. Write the query
query = f"""

SELECT  *
FROM '{TRANSACTIONS_TABLE}'
limit 100
"""

# %%
# 3. Time and execute the query
start_time = time.time()
df_flagged = pd.read_sql_query(query, conn)
elapsed = time.time() - start_time

print(f" Query executed in {elapsed:.4f} seconds across millions of rows!\n")

# 4. Display the DataFrame in the notebook output
df_flagged
# Out:
# C:\Users\faisal\AppData\Local\Temp\ipykernel_9608\2414382148.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_flagged = pd.read_sql_query(query, conn)
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 3. Time and execute the query
#       2 start_time = time.time()
# ----> 3 df_flagged = pd.read_sql_query(query, conn)
#       4 elapsed = time.time() - start_time
#       6 print(f" Query executed in {elapsed:.4f} seconds across millions of rows!\n")
#
# File ~\AppData\Local\miniconda3\envs\polars\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\AppData\Local\miniconda3\envs\polars\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\AppData\Local\miniconda3\envs\polars\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2700 cur = self.con.cursor()
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#    2704 except Error as exc:
#
# CatalogException: Catalog Error: Table with name transactions does not exist!
# Did you mean "duckdb_constraints"?
#
# LINE 3: FROM transactions
#              ^
